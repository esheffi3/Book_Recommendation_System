# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
books = pd.read_csv('data/BX-Books.csv', sep=";", on_bad_lines='skip', encoding='latin-1')
# Out:
# C:\Users\17742\AppData\Local\Temp\ipykernel_4864\1151697202.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('data/BX-Books.csv', sep=";", on_bad_lines='skip', encoding='latin-1')

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
books.iloc[237]['Image-URL-L']
# Out:
# 'http://images.amazon.com/images/P/0671027387.01.LZZZZZZZ.jpg'

# %%
books.shape
# Out:
# (271360, 8)

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher',
#        'Image-URL-S', 'Image-URL-M', 'Image-URL-L'],
#       dtype='object')

# %%
books = books[['ISBN','Book-Title', 'Book-Author', 'Year-Of-Publication', 'Publisher','Image-URL-L']]

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
# Lets remane some wierd columns name
books.rename(columns={"Book-Title":'title',
                      'Book-Author':'author',
                     "Year-Of-Publication":'year',
                     "Publisher":"publisher",
                     "Image-URL-L":"image_url"},inplace=True)

# %%
books.head()
# Out:
#          ISBN                                              title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#                  author  year                   publisher  \
# 0    Mark P. O. Morford  2002     Oxford University Press
# 1  Richard Bruce Wright  2001       HarperFlamingo Canada
# 2          Carlo D'Este  1991             HarperPerennial
# 3      Gina Bari Kolata  1999        Farrar Straus Giroux
# 4       E. J. W. Barber  1999  W. W. Norton &amp; Company
#
#                                            image_url
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# ...

# %%
users = pd.read_csv('data/BX-Users.csv', sep=";", on_bad_lines='skip', encoding='latin-1')

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
users.shape
# Out:
# (278858, 3)

# %%
users.rename(columns={"User-ID":'user_id',
                      'Location':'location',
                     "Age":'age'},inplace=True)

# %%
users.head(2)
# Out:
#    user_id                   location   age
# 0        1         nyc, new york, usa   NaN
# 1        2  stockton, california, usa  18.0

# %%
ratings = pd.read_csv('data/BX-Book-Ratings.csv', sep=";", on_bad_lines='skip', encoding='latin-1')

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
ratings.shape
# Out:
# (1149780, 3)

# %%
ratings.rename(columns={"User-ID":'user_id',
                      'Book-Rating':'rating'},inplace=True)

# %%
ratings.head(2)
# Out:
#    user_id        ISBN  rating
# 0   276725  034545104X       0
# 1   276726  0155061224       5

# %%
print(books.shape, users.shape, ratings.shape, sep='\n')
# Out:
# (271360, 6)
# (278858, 3)
# (1149780, 3)

# %%
ratings['user_id'].value_counts()
# Out:
# user_id
# 11676     13602
# 198711     7550
# 153662     6109
# 98391      5891
# 35859      5850
#           ...
# 116180        1
# 116166        1
# 116154        1
# 116137        1
# 276723        1
# Name: count, Length: 105283, dtype: int64

# %%
ratings['user_id'].value_counts().shape
# Out:
# (105283,)

# %%
ratings['user_id'].unique().shape
# Out:
# (105283,)

# %%
x = ratings['user_id'].value_counts() >= 50

# %%
x[x].shape
# Out:
# (3427,)

# %%
y= x[x].index

# %%
y
# Out:
# Index([ 11676, 198711, 153662,  98391,  35859, 212898, 278418,  76352, 110973,
#        235105,
#        ...
#         14374, 270801, 141157, 154844, 214717,  22409, 265784, 261685, 103630,
#        144478],
#       dtype='int64', name='user_id', length=3427)

# %%
ratings = ratings[ratings['user_id'].isin(y)]

# %%
ratings.head()
# Out:
#      user_id        ISBN  rating
# 173   276847  0446364193       0
# 174   276847  3257200552       5
# 175   276847  3379015180       0
# 176   276847  3404145909       8
# 177   276847  3404148576       8

# %%
ratings.shape
# Out:
# (768472, 3)

# %%
ratings_with_books = ratings.merge(books, on='ISBN')

# %%
ratings_with_books.head()
# Out:
#    user_id        ISBN  rating                                    title  \
# 0   276847  0446364193       0  Along Came a Spider (Alex Cross Novels)
# 1   276847  3379015180       0                          Schlafes Bruder
# 2   276847  3404145909       8                    Der Stein der Kelten.
# 3   276847  3404148576       8                               Nordermoor
# 4   276847  3404921178       7              Nur der Tod ist ohne Makel.
#
#                 author  year        publisher  \
# 0      James Patterson  1993     Warner Books
# 1     Robert Schneider  1994  Reclam, Leipzig
# 2     Michael Phillips  2001         LÃ?Â¼bbe
# 3  Arnaldur Indridason  2003         LÃ?Â¼bbe
# 4          Ann Granger  2002         LÃ?Â¼bbe
#
#                                            image_url
# 0  http://images.amazon.com/images/P/0446364193.0...
# 1  http://images.amazon.com/images/P/3379015180.0...
# 2  http://images.amazon.com/images/P/3404145909.0...
# ...

# %%
ratings_with_books.shape
# Out:
# (703434, 8)

# %%
number_rating = ratings_with_books.groupby('title')['rating'].count().reset_index()

# %%
number_rating.head()
# Out:
#                                                title  rating
# 0   A Light in the Storm: The Civil War Diary of ...       4
# 1                              Always Have Popsicles       1
# 2               Apple Magic (The Collector's series)       1
# 3   Ask Lily (Young Women of Faith: Lily Series, ...       1
# 4   Beyond IBM: Leadership Marketing and Finance ...       1

# %%
number_rating.rename(columns={'rating':'num_of_rating'},inplace=True)

# %%
number_rating.head()
# Out:
#                                                title  num_of_rating
# 0   A Light in the Storm: The Civil War Diary of ...              4
# 1                              Always Have Popsicles              1
# 2               Apple Magic (The Collector's series)              1
# 3   Ask Lily (Young Women of Faith: Lily Series, ...              1
# 4   Beyond IBM: Leadership Marketing and Finance ...              1

# %%
final_rating = ratings_with_books.merge(number_rating, on='title')

# %%
final_rating.head()
# Out:
#    user_id        ISBN  rating                                    title  \
# 0   276847  0446364193       0  Along Came a Spider (Alex Cross Novels)
# 1   276847  3379015180       0                          Schlafes Bruder
# 2   276847  3404145909       8                    Der Stein der Kelten.
# 3   276847  3404148576       8                               Nordermoor
# 4   276847  3404921178       7              Nur der Tod ist ohne Makel.
#
#                 author  year        publisher  \
# 0      James Patterson  1993     Warner Books
# 1     Robert Schneider  1994  Reclam, Leipzig
# 2     Michael Phillips  2001         LÃ?Â¼bbe
# 3  Arnaldur Indridason  2003         LÃ?Â¼bbe
# 4          Ann Granger  2002         LÃ?Â¼bbe
#
#                                            image_url  num_of_rating
# 0  http://images.amazon.com/images/P/0446364193.0...            198
# 1  http://images.amazon.com/images/P/3379015180.0...             10
# ...

# %%
final_rating.shape
# Out:
# (703434, 9)

# %%
final_rating = final_rating[final_rating['num_of_rating'] >= 50]

# %%
final_rating.head()
# Out:
#     user_id        ISBN  rating  \
# 0    276847  0446364193       0
# 47   276925  002542730X      10
# 52   276925  0140327592       0
# 59   276925  0316666343       0
# 62   276925  0385504209       8
#
#                                                 title             author  \
# 0             Along Came a Spider (Alex Cross Novels)    James Patterson
# 47  Politically Correct Bedtime Stories: Modern Ta...  James Finn Garner
# 52                                            Matilda         Roald Dahl
# 59                          The Lovely Bones: A Novel       Alice Sebold
# 62                                  The Da Vinci Code          Dan Brown
#
#     year                  publisher  \
# 0   1993               Warner Books
# 47  1994  John Wiley &amp; Sons Inc
# 52  1990         Viking Penguin Inc
# 59  2002              Little, Brown
# 62  2003                  Doubleday
#
#                                             image_url  num_of_rating
# ...

# %%
final_rating.shape
# Out:
# (135998, 9)

# %%
final_rating.drop_duplicates(['user_id','title'],inplace=True)

# %%
final_rating.shape
# Out:
# (133264, 9)

# %%
book_pivot = final_rating.pivot_table(columns='user_id', index='title', values= 'rating')

# %%
book_pivot
# Out:
# user_id                                             183     243     254     \
# title
# 1984                                                   NaN     NaN     9.0
# 1st to Die: A Novel                                    NaN     NaN     NaN
# 2010: Odyssey Two                                      NaN     NaN     NaN
# 204 Rosewood Lane                                      NaN     NaN     NaN
# 24 Hours                                               NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Year of Wonders                                        NaN     NaN     NaN
# You Belong To Me                                       NaN     NaN     NaN
# Zen and the Art of Motorcycle Maintenance: An I...     NaN     NaN     NaN
# Zoya                                                   NaN     NaN     NaN
# \O\" Is for Outlaw"                                    NaN     NaN     NaN
#
# ...

# %%
book_pivot.shape
# Out:
# (1388, 3274)

# %%
book_pivot.fillna(0, inplace=True)

# %%
book_pivot
# Out:
# user_id                                             183     243     254     \
# title
# 1984                                                   0.0     0.0     9.0
# 1st to Die: A Novel                                    0.0     0.0     0.0
# 2010: Odyssey Two                                      0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 24 Hours                                               0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Year of Wonders                                        0.0     0.0     0.0
# You Belong To Me                                       0.0     0.0     0.0
# Zen and the Art of Motorcycle Maintenance: An I...     0.0     0.0     0.0
# Zoya                                                   0.0     0.0     0.0
# \O\" Is for Outlaw"                                    0.0     0.0     0.0
#
# ...

# %%
from scipy.sparse import csr_matrix

# %%
book_sparse = csr_matrix(book_pivot)

# %%
type(book_sparse)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
from sklearn.neighbors import NearestNeighbors
model = NearestNeighbors(algorithm= 'brute')

# %%
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
distance, suggestion = model.kneighbors(book_pivot.iloc[237,:].values.reshape(1,-1), n_neighbors=6 )

# %%
distance
# Out:
# array([[ 0.        , 57.46303159, 58.20652884, 58.50640991, 58.51495535,
#         58.63446086]])

# %%
suggestion
# Out:
# array([[ 237, 1259,  615, 1096, 1197,  825]], dtype=int64)

# %%
book_pivot.iloc[241,:]
# Out:
# user_id
# 183       0.0
# 243       0.0
# 254       0.0
# 507       0.0
# 626       0.0
#          ...
# 278188    0.0
# 278418    0.0
# 278582    0.0
# 278633    0.0
# 278843    0.0
# Name: Crocodile on the Sandbank, Length: 3274, dtype: float64

# %%
for i in range(len(suggestion)):
    print(book_pivot.index[suggestion[i]])
# Out:
# Index(['Cradle and All', 'The Web (Alex Delaware Series, No. 10)',
#        'Mixed Blessings', 'The Judge', 'The Sands of Time', 'Shadows'],
#       dtype='object', name='title')

# %%
book_pivot.index[3]
# Out:
# '204 Rosewood Lane'

# %%
book_names = book_pivot.index

# %%
book_names[2]
# Out:
# '2010: Odyssey Two'

# %%
np.where(book_pivot.index == '4 Blondes')[0][0]
# Out:
# 6

# %%
ids = np.where(final_rating['title'] == "Harry Potter and the Chamber of Secrets (Book 2)")[0][0]

# %%
final_rating.iloc[ids]['image_url']
# Out:
# 'http://images.amazon.com/images/P/0439064864.01.LZZZZZZZ.jpg'

# %%
book_name = []
for book_id in suggestion:
    book_name.append(book_pivot.index[book_id])

# %%
book_name[0]
# Out:
# Index(['Cradle and All', 'The Web (Alex Delaware Series, No. 10)',
#        'Mixed Blessings', 'The Judge', 'The Sands of Time', 'Shadows'],
#       dtype='object', name='title')

# %%
ids_index = []
for name in book_name[0]: 
    ids = np.where(final_rating['title'] == name)[0][0]
    ids_index.append(ids)

# %%
for idx in ids_index:
    url = final_rating.iloc[idx]['image_url']
    print(url)
# Out:
# http://images.amazon.com/images/P/0446609404.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/055357227X.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/0385299109.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/0515119644.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/0688065716.01.LZZZZZZZ.jpg
# http://images.amazon.com/images/P/0553560271.01.LZZZZZZZ.jpg

# %%
import pickle
pickle.dump(model,open('artifacts/model.pkl','wb'))
pickle.dump(book_names,open('artifacts/book_names.pkl','wb'))
pickle.dump(final_rating,open('artifacts/final_rating.pkl','wb'))
pickle.dump(book_pivot,open('artifacts/book_pivot.pkl','wb'))

# %%
def recommend_book(book_name):
    book_id = np.where(book_pivot.index == book_name)[0][0]
    distance, suggestion = model.kneighbors(book_pivot.iloc[book_id,:].values.reshape(1,-1), n_neighbors=6 )
    
    for i in range(len(suggestion)):
            books = book_pivot.index[suggestion[i]]
            for j in books:
                if j == book_name:
                    print(f"You searched '{book_name}'\n")
                    print("The suggestion books are: \n")
                else:
                    print(j)

# %%
book_name = "Harry Potter and the Chamber of Secrets (Book 2)"
recommend_book(book_name)
# Out:
# You searched 'Harry Potter and the Chamber of Secrets (Book 2)'
#
# The suggestion books are:
#
# Harry Potter and the Goblet of Fire (Book 4)
# Harry Potter and the Prisoner of Azkaban (Book 3)
# Harry Potter and the Sorcerer's Stone (Book 1)
# The Charm School
# All I Need Is You

# %%
# Visualizing the distribution of ratings
plt.figure(figsize=(8, 6))
sns.histplot(data=ratings, x='rating', binwidth=1, kde=False)
plt.title('Distribution of Book Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

import matplotlib.pyplot as plt
import seaborn as sns

# Count the number of ratings each book has received
book_rating_counts = ratings.groupby('ISBN').size().reset_index(name='num_ratings')

# Merge with the books dataframe to get the book titles
book_rating_counts = book_rating_counts.merge(books, on='ISBN')

import matplotlib.pyplot as plt
import seaborn as sns

# Count the number of ratings each user has given
user_rating_counts = ratings.groupby('user_id').size().reset_index(name='num_ratings')

# Plotting the data
plt.figure(figsize=(10, 6))
sns.histplot(user_rating_counts['num_ratings'], bins=50, kde=False, log_scale=True)
plt.title('Distribution of Number of Ratings Per User')
plt.xlabel('Number of Ratings')
plt.ylabel('Number of Users')
plt.xscale('log')  # Using a logarithmic scale if the distribution is skewed
plt.show()
